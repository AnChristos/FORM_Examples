# %%
from FormUtils import pyForm, capture_physics_expr

# %%
# %%pyForm Renormalization
#
# * Process: Renormalization
#
# #-
# * Above suppresses extra output
# Off Statistics;
# Off FinalStats;
#
# Symbol dim;
# Dimension dim;
# #include FeynHelpers.h
#
# Vectors k1,k2;
# Symbols e, Mmuon, Melec;
# Symbols y, D1, D2, bubbleProp;
# Symbols qmu1, qmu2, gmu1mu2;
#
# CF  A, A0, B, B0, B00, B1, B11;
#
#
# #message "This bubble is inside a 4D integral "
# Local Bubble = (-e^2)
#              * g(i1, i2, mu1) * fprop(i2, i3, k1, Melec)
#              * g(i3, i4, mu2) * fprop(i4, i1, k2, Melec);
# #message "This is the row Loop electron bubble "
# Print +ss Bubble;
#
# #call Propagators()
# #call doTrace(1,1)
# .sort
# #message ">>> STEP 1: Bubble after traces"
# Print +s Bubble ;
# .sort
#
# id k2 = k1 - q;
# id k2(mu1) = k1(mu1) - q(mu1);
# id k2(mu2) = k1(mu2) - q(mu2);
# .sort
# #message ">>> STEP 2: after k2 = k1 - q"
# print +s Bubble;
# .sort
# id q.k2 = q.k1 - q.q;
# id k2.k2 = k1.k1 + q.q - 2*q.k1;
# .sort
# #message ">>> STEP 3: expanded scalar products"
# print +s Bubble;
# .sort
# id prop(-Melec^2 + k1.k1) = D1;
# id prop(-Melec^2 + k2.k2) = D2;
# .sort
# #message ">>> STEP 4: denominators defined"
# print +s Bubble;
# .sort
# id D1*D2 = bubbleProp;
# .sort
# #message ">>> STEP 5: loop integrand formed"
# print +s Bubble;
# .sort
#
# id bubbleProp*q(mu1?)*k1(mu2?) = q(mu1)*q(mu2)*B1(q,Melec,Melec);
# id bubbleProp*k1(mu1?)*k1(mu2?) = d_(mu1,mu2)*B00(q,Melec,Melec)
#                                 + q(mu1)*q(mu2)*B11(q,Melec,Melec);
# id bubbleProp = B0(q,Melec,Melec);
# .sort
# #message ">>> STEP 6: PV reduction done"
# print +s Bubble;
# .sort
#
# Local WardTest = q(mu1) * Bubble;
# .sort
# #message ">>> STEP 7: Ward test constructed"
# print +s WardTest;
# .sort
#
# .end
# Out:
# FORM 5.0.0 (Jan 27 2026, v5.0.0)                 Run: Sun Apr 19 21:34:15 2026
#
#     * Process: Renormalization
#
#     #-
#
# ~~~"This bubble is inside a 4D integral "
# ~~~"This is the row Loop electron bubble "
#
#    Bubble =
#        -
#          g(i1,i2,mu1)
#          *g(i2,i3)
#          *g(i3,i4,mu2)
#          *g(i4,i1)
#          *prop( - Melec^2 + k1.k1)
#          *prop( - Melec^2 + k2.k2)
#          *e^2*Melec^2
#        -
#          g(i1,i2,mu1)
#          *g(i2,i3)
#          *g(i3,i4,mu2)
#          *g(i4,i1,k2)
#          *prop( - Melec^2 + k1.k1)
#          *prop( - Melec^2 + k2.k2)
#          *e^2*Melec
#        -
#          g(i1,i2,mu1)
#          *g(i2,i3,k1)
#          *g(i3,i4,mu2)
#          *g(i4,i1)
#          *prop( - Melec^2 + k1.k1)
#          *prop( - Melec^2 + k2.k2)
#          *e^2*Melec
#        -
#          g(i1,i2,mu1)
#          *g(i2,i3,k1)
#          *g(i3,i4,mu2)
#          *g(i4,i1,k2)
#          *prop( - Melec^2 + k1.k1)
# ...
