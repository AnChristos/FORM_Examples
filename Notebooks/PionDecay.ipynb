# %%
from FormUtils import pyForm, capture_physics_expr

# %%
# %%pyForm PionDecay
#
# * Process: pion -> fermion anti-neutrino
#
# #-
# * Above suppresses extra output
# Off Statistics;
# Off FinalStats;
#
# #include amplitude.inc
#
# * Massess
# Symbols  ml, mpi;
# Vector pPion;
#
# * I will ommit constants as we want to take a ratio.
# * This should be multiplied by a constant which I ommit
# Local M =  UB(i1, p3, ml) * (g(i1, i2) - g(i1, i2, k5)) * g(i2, i3, mu1) * V(i3, p4, 0)  * pPion(mu1);
#
# #call squareamplitude(M, Msq)
# multiply -1; * This is due to conventions
# .sort
#
# * --- Kinematics ---
# id p3.p3 = ml^2;
# id p4.p4 = 0;
# id pPion.pPion = mpi^2;
# id p3.p4 = (mpi^2 - ml^2)/2;
# id pPion.p3 = (mpi^2 + ml^2)/2;
# id pPion.p4 = (mpi^2 - ml^2)/2;
# .sort
#
#
# * Differential Decay Rate (I ommit 32 pi^2 * m_pi^3)
# Local dGamma = ( pRest) * Msq;
# .sort
# id pRest = (mpi^2 - ml^2);
# .sort
#
#
# bracket mpi;
# .sort
# * Save to file
# Format C;
# #write <PionDecay.txt> "%e;", dGamma;
# .sort
# * Print
# Format;
# Print Msq;
# Print dGamma;
# .end
#
# .end
# Out:
# FORM 5.0.0 (Jan 27 2026, v5.0.0)                 Run: Fri Apr 10 21:38:38 2026
#
#     * Process: pion -> fermion anti-neutrino
#
#     #-
#
#    Msq =
#       4*ml^2*mpi^2 - 4*ml^4;
#
#    dGamma =
#       4*ml^2*mpi^4 - 8*ml^4*mpi^2 + 4*ml^6;

# %%
import numpy as np

# Capture 
form_expr = capture_physics_expr("scripts/PionDecay.txt")
print(f"Captured Expression: {form_expr}")

el = eval(form_expr, {
            "ml": 0.51099895069, 
            "mpi": 139.57039, 
        })

muon = eval(form_expr, {
            "ml": 105.6583755, 
            "mpi": 139.57039, 
        })



print(f"Ratio electron to muon: {el/muon:.2e}")
# Out:
# Captured Expression: +pow(mpi,2)*(-8*pow(ml,4))+pow(mpi,4)*(4*pow(ml,2))+4*pow(ml,6)
# Ratio electron to muon: 1.28e-04
